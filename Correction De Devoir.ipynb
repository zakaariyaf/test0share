# %%
#Exercice 1
List1=[1,5,9,6,8]
#1
print(len(List1))
#2
print(List1)
# Out:
# 5
# [1, 5, 9, 6, 8]

# %%
#Exercice 2
Chain="Bonjour tout le monde !"
#1
print(Chain)
#2
Nombredemot=Chain.split(' ')
print(len(Nombredemot))
print(Nombredemot)
# Out:
# Bonjour tout le monde !
# 5
# ['Bonjour', 'tout', 'le', 'monde', '!']

# %%
#Exercice 3
Chain="Bonjour tout le monde !"
#1
F=open("fich1.txt","w")
F.write(Chain)
F.close()
#2
R=open("fich1.txt","a")
R.writelines("\nA bientôt")
R.close()
#3
print(open("fich1.txt","r").readlines())
#4
M = open("fich1.txt","r")
S=M.readlines()
for x in S:
    print(x)
M.close()
# Out:
# ['Bonjour tout le monde !\n', 'A bientôt']
# Bonjour tout le monde !
#
# A bientôt

# %%
#Exercice 4
F=open("fich1.txt","r")
Fi=F.readlines()
F.close()
R=open("fich2.txt","w")
R.writelines(Fi)
R.close()

# %%
#Exercice 5
import pandas as pd
F=pd.read_csv("emp.csv")
#1
print(F)
print("\n")
#2
print(F["Username"])
print("\n")
#3
y=F[(F.Ville=="Casa")]
print(y)
print("\n")
#4
x=float(input("Donne un Salaire pour Filtrer l Egalité"))
y=F[(F.Salaire==x)]
print(y)
print("\n")
#5
x=float(input("Donne un Salaire pour Filtrer le salair inferieur"))
y=F[(F.Salaire<x)]
print(y)
print("\n")
# Out:
#    Username  Salaire      Ville Last name
# 0       Ali     9000       Casa    Booker
# 1  Zakariya     8000        Fes      Grey
# 2     Ayoub     5000       Casa   Johnson
# 3     Ahmed     8000  El jadida   Jenkins
# 4      Saad     8000       Sale     Smith
#
#
# 0         Ali
# 1    Zakariya
# 2       Ayoub
# 3       Ahmed
# 4        Saad
# Name: Username, dtype: object
#
#
#   Username  Salaire Ville Last name
# 0      Ali     9000  Casa    Booker
# 2    Ayoub     5000  Casa   Johnson
#
#
# Donne un Salaire pour Filtrer l Egalité8000
#    Username  Salaire      Ville Last name
# 1  Zakariya     8000        Fes      Grey
# 3     Ahmed     8000  El jadida   Jenkins
# 4      Saad     8000       Sale     Smith
#
#
# Donne un Salaire pour Filtrer le salair inferieur8000
#   Username  Salaire Ville Last name
# 2    Ayoub     5000  Casa   Johnson

# %%
#Exercice 6
import pandas as pd
F=pd.read_csv("movies.csv")
#1
print(F["title"])
print("\n")
#2
y=F[F.title.str.startswith('The')]
print(y.title)
print("\n")
#3
xo=input('Donner une annee')
xoo=0
y=F["title"]
for x in range(len(y)):
    indx=len(y[x])
    s=y[x]
    if s[indx-5:indx-1]==xo:
        print(F.iloc[x,:])
        print("-------------------------------------")
        xoo+=1
#4
print("\n le Nombre des films est {}".format(xoo))
# Out:
# 0                                Toy Story (1995)
# 1                                  Jumanji (1995)
# 2                         Grumpier Old Men (1995)
# 3                        Waiting to Exhale (1995)
# 4              Father of the Bride Part II (1995)
#                           ...
# 9737    Black Butler: Book of the Atlantic (2017)
# 9738                 No Game No Life: Zero (2017)
# 9739                                 Flint (2017)
# 9740          Bungo Stray Dogs: Dead Apple (2018)
# 9741          Andrew Dice Clay: Dice Rules (1991)
# Name: title, Length: 9742, dtype: object
#
#
# 537                       Theodore Rex (1995)
# 1236              The Devil's Advocate (1997)
# 1342                  The Players Club (1998)
# 1404      There's Something About Mary (1998)
# 1700                             Them! (1954)
#                         ...
# 9679      The Tale of the Bunny Picnic (1986)
# 9684                       The Clapper (2018)
# ...

# %%
#Exercice 7
x1="Bonjour Alami"
x2="Bonsoir Alami"
x1=set(x1.split(' '))
x2=set(x2.split(' '))
print(len(x1&x2))
print((len(x1|x2)))
print(len(x1&x2)/(len(x1|x2)))
# Out:
# 1
# 3
# 0.3333333333333333
# 4
